# %% [markdown]
# # 파이썬 기초

# %% [markdown]
# ## 1.1 Print 기초

# %%
# 문자
print("주피터랩이 처음이에요.")
# 숫자
print(1234)
# Out:
# 주피터랩이 처음이에요.
# 1234

# %%
# 문자 + 문자
print("주피터랩이 "+ "처음이에요.")
# 숫자 + 숫자
print(1234 + 2345)
# Out:
# 주피터랩이 처음이에요.
# 3579

# %%
# 문자 숫자
print("주피터랩이 "+"1234")
# Out:
# 주피터랩이 1234

# %% [markdown]
# - **문자+숫자 => 에러 Error**
# > 자료형 다름 연산 불가함
#
# ![image.png](attachment:2b9e5416-116a-49cd-b873-a5f24441aadf.png)

# %%
# 문자 X 숫자 => 반복
print("="*20)
print("안녕"*5)
print("="*20)
# Out:
# ...
# 안녕안녕안녕안녕안녕
# ...

# %% [markdown]
# <hr/>

# %%
# print 심화1
print("="*20, end='')
print("안녕"*5, end='')
print("="*20, end='')
# Out:
# ====================안녕안녕안녕안녕안녕====================

# %% [markdown]
# > 마지막에 end='' 를 이용하여 줄바꿈 제거

# %%
# print 심화2
print("안녕","하시","겠읍니까","?",sep=".")
print(1,2,3,4,5 , sep="/")
# Out:
# 안녕.하시.겠읍니까.?
# 1/2/3/4/5

# %%
# print 응용
import time as t
print("딸")
t.sleep(1)
print("기")
t.sleep(1)
print("모")
t.sleep(1)
print("찌")
t.sleep(1)
# Out:
# 앙
# 기
# 모
# 띠

# %%
# print 응용2
import time as t
print("기대하세요",end='\r')
t.sleep(1.5)
print("드디어~~~",end='\r')
t.sleep(1.5)
print("개봉합니다",end='\r')
t.sleep(1.5)
# Out:
# 개봉합니다~

# %% [markdown]
# ## 1.2 숫자형

# %%
# 정수형
a = 123
b = -321
c = 0

# %%
print(a,b,c, sep = '\n')
# Out:
# 123
# -321
# 0

# %%
# 실수형
aa =  3.141592
bb = -12.34
cc = 3.14E10
dd = 3.14E-10
print(aa,bb,cc,dd, sep = '\n')
# Out:
# 3.141592
# -12.34
# 31400000000.0
# 3.14e-10

# %%
# 2진수(bin)
aaa = 0b1101
bbb = 0o177
ccc = 0x8ff

print(aaa,bbb,ccc, sep = '\n')
# Out:
# 13
# 127
# 2303

# %%
# 16진수

# %% [markdown]
# <hr/>

# %% [markdown]
# ## 1.3 사칙연산

# %%
# 사칙연산 예
sa = 77
san = 13
print('덧셈:', sa + san)
print('뺄셈:', sa - san)
print('곱셈:',sa*san)
print('나눗셈:', sa/san)
print('몫:', sa//san)
print('나머지', sa%san)
print('승', sa + san)
# Out:
# 덧셈: 90
# 뺄셈: 64
# 곱셈: 1001
# 나눗셈: 5.923076923076923
# 몫: 5
# 나머지 12
# 승 90

# %%
# 48p 1분 
print(10*18**2+2*11)
# Out:
# 3262

# %%
#복합연산자
a = 1
a = a + 1
a += a + 1
print (a)
# Out:
# 5

# %% [markdown]
# ## 1.4 문자열 자료형

# %%
str1 = "안녕" + '하세요'
str2 = "안녕하세요 '홍길동' 이라고 합니다."
str3 = '안녕하세요 "홍길동" 이라고 합니다.'
str4 = """저는 여러줄을 작성합니다."""
str5 = '''저는 여러줄을 작성합니다.'''
str6 = "저는\n여러줄을\n작성합니다."
str7 = "안녕하세요 \"홍길동\" 이라고 합니다"
print(str1,str2,str3,str4,str5,str6,str7, sep='\n')
# Out:
# 안녕하세요
# 안녕하세요 '홍길동' 이라고 합니다.
# 안녕하세요 "홍길동" 이라고 합니다.
# 저는 여러줄을 작성합니다.
# 저는 여러줄을 작성합니다.
# 저는
# 여러줄을
# 작성합니다.
# 안녕하세요 "홍길동" 이라고 합니다

# %%
#문자열 길이 구하기
a = "Life is too short" + '는 '
print(a+str(len(a))+" 자 입니다")
# Out:
# Life is too short는 19 자 입니다

# %%
#문자열 인덱싱
a = "Life is too short, You need Python"

# %%
print(a[1] + a[8])
# Out:
# it

# %%
#문자열 인덱싱으로 글자 만들기
a = "Life is too short, You need Python"
word = a[13]+a[14]+a[21]+a[12]+a[3]
print(word)
# Out:
# house

# %%
#슬라이싱
a = "Life is too short, You need Python"
#단어
print(a[12:17])
#문장
print(a[:19])
# Out:
# short
# Life is too short,

# %%
a = "20230331Rainy"
year = a[:4]
date = a[4:8]
weather = a[8:]
print(year)
print(date)
print(weather
# Out:
# 2023
# 0331
# Rainy

# %%
#문제
today = '20260203오늘은쌀쌀하다'
year = today[:4]
month = today[4:6]
date = today[6:8]
word_1 = today[8:11]
word_2 = today [11:15]

print(year+"년 "+month+"월 "+date+"일 "+word_1+" "+word_2+".")
# Out:
# 2026년 02월 03일 오늘은 쌀쌀하다.

# %%
#테스트
import time as t
# dir(t)
# Out:
# ['CLOCK_BOOTTIME',
#  'CLOCK_MONOTONIC',
#  'CLOCK_MONOTONIC_RAW',
#  'CLOCK_PROCESS_CPUTIME_ID',
#  'CLOCK_REALTIME',
#  'CLOCK_TAI',
#  'CLOCK_THREAD_CPUTIME_ID',
#  '_STRUCT_TM_ITEMS',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'altzone',
#  'asctime',
#  'clock_getres',
#  'clock_gettime',
#  'clock_gettime_ns',
#  'clock_settime',
#  'clock_settime_ns',
#  'ctime',
#  'daylight',
#  'get_clock_info',
#  'gmtime',
#  'localtime',
#  'mktime',
#  'monotonic',
#  'monotonic_ns',
#  'perf_counter',
#  'perf_counter_ns',
#  'process_time',
#  'process_time_ns',
#  'pthread_getcpuclockid',
#  'sleep',
#  'strftime',
#  'strptime',
#  'struct_time',
#  'thread_time',
#  'thread_time_ns',
#  'time',
#  'time_ns',
#  'timezone',
#  'tzname',
#  'tzset']

# %%
import requests as req
url = "https://v.daum.net/v/20260203120146996"
res = req.get(url).text
print(res.find("급락"))
print(res.find("증폭"))
print(res[res.find("급락"):res.find("증폭")])
# Out:
# 374
# 400
# 급락 하루만에 급등… ‘널뛰기 장세’ 불확실성

# %%
import requests as req
url = "https://v.daum.net/v/20260203120206039"
res = req.get(url).text
print(res.find("오영석 박사는"))
print(res.find("계획"))
print(res[res.find("오영석 박사는"):res.find("계획")+3])

positions = []
start = 0
while True:
    idx = res.find("오영석", start)
    if idx == -1:
        break
    positions.append(idx)
    start = idx + 1
print(positions)
# Out:
# 17496
# 17565
# 오영석 박사는 "앞으로 고내열 수지와 결합해 적정 온도를 500℃ 수준까지 끌어올리고, 실제 부품 환경에서 신뢰성을 검증할 계획"
# [1357, 16597, 17496]

# %%
import requests as req
url = "https://api4.binance.com/api/v3/ticker/price?symbol=BTCUSDT"
res = req.get(url).text
print(res)
BTC_dollar = res[res.find("price")+8:res.find(".")]
KRW = 1448
money = str(int(BTC_dollar)*int(KRW))
print(money+"원")
print(money[0]+"억"+money[1:5]+"만"+money[5:]+"원")
won = str(int(BTC_dollar)*int(KRW))
# Out:
# {"symbol":"BTCUSDT","price":"78423.66000000"}
# 113556504원
# 1억1355만6504원

# %% [markdown]
# ### 1.4.1 문자열 포매팅

# %%
# 문자열 포매팅, 대입
app = 3
print("나는 사과를 %d개 먹었다." % app)
# Out:
# 나는 사과를 3개 먹었다.

# %%
inp = input("사과를 몇개 먹었니?.")
print("나는 사과를 %s개 먹었다." % (int(inp) * 10))
# Out:
# 사과를 몇개 먹었니?. 10
# 나는 사과를 100개 먹었다.

# %%
#문자열 포매팅 2개 이상의 값 넣기
won = 2000
ea = input("몇개인지 입력하세요.")
# Out:
# 몇개인지 입력하세요. 9

# %%
#문자열
print("%s" % '12.34 문자표현')
#정수
print("%d")
# Out:
# 12.34 문자표현
# %d

# %%
#숫자 값을 가진 변수로 대입하기
ss = "I eat {0} apples".format("five")
print(ss, type(ss))
# Out:
# I eat five apples <class 'str'>

# %%
#2개 이상 값 넣기
s = "five"
e = 7
ss = "I eat {0} apples, so I was sick for {1} days.".format(s,e)
print(ss, type(ss))
# Out:
# I eat five apples, so I was sick for 7 days. <class 'str'>

# %%
sss = "I eat {0} apples, so I was sick for {day} days.".format(10,day=3)
print(sss)
# Out:
# I eat 10 apples, so I was sick for 3 days.

# %%
#한잔에 2500원인 라떼와 3800원인 라떼를 게산한 영수증을 출력하라.

americano = input("아메리카노 몇 잔을 드시겠습니까?")
latte = input("라떼를 몇 잔을 드시겠습니까?")
line_1 = "========================================="
line_2 = "-----------------------------------------"

print(line_1+"\n"+"영수증"+line_1+"\n"+"아이스 아메리카노 %s잔"+"\n"+"라떼 %s잔")
# Out:
# 아메리카노 몇 잔을 드시겠습니까? 10
# 라떼를 몇 잔을 드시겠습니까? 10
# ...
# -----------------------------------------

# %% [markdown]
# ### 무자열 포멧팅

# %%
name= '홍길동'
age =30
print(f"나의 이름은 {name} 입니다... , 나이는 {age} 살 입니다.")
# Out:
# 나의 이름은홍길동 입니다... , 나이는 30 살 입니다.

# %%
d={'name' : '홍길동','age' :30}
name= '홍길동'
age =30
print(f"나의 이름은 {d['name']} 입니다. 나이는 {d['age']} 살 입니다.")
# Out:
# 나의 이름은 홍길동 입니다. 나이는 30 살 입니다.

# %%
#f 포메팅에서 주의 할 점
#딕셔너리의 값을 표현할 때 괄호로 묶어 표기하고 공백을 주의하라

d={'name' : '홍길동','age' :30}
name= '홍길동'
age =30
print(f"나의 이름은 {d['name']:^10} 입니다. 나이는 {d['age']} 살 입니다.")
# Out:
# 나의 이름은    홍길동     입니다. 나이는 30 살 입니다.

# %%
import requests as req
url = "https://api4.binance.com/api/v3/ticker/price?symbol=BTCUSDT"
res = req.get(url).text
print(res)
BTC_dollar = res[res.find("price")+8:res.find(".")]
KRW = 1448
money = str(int(BTC_dollar)*int(KRW))
print(money+"원")
print(money[0]+"억"+money[1:5]+"만"+money[5:]+"원")
won = str(int(BTC_dollar)*int(KRW))
# Out:
# {"symbol":"BTCUSDT","price":"76110.77000000"}
# 110207280원
# 1억1020만7280원

# %%
#count  문자 개수 세기
a="hobby"
b="appleppp"
print(a.count('b'))
print(b.count('p'))
# Out:
# 2
# 5

# %%
#find 위치 알려주기 1
a = "python is the best choice"
print(a.find('p'))
print(a.find('b'))
print(a.find('x'))
# Out:
# 0
# 14
# -1

# %%
#조인 연습
nn = '123456789'
print("빠 ".join(nn) + "빠")
# Out:
# 1빠 2빠 3빠 4빠 5빠 6빠 7빠 8빠 9빠

# %%
#upper - 소문자를 대문자로 바꾸기
a = 'Python is the best choice'
print(a.upper())
#Lower - 대문자를 소문자로 바꾸기
b = 'python is the best choice'
print(b.lower())

c = 'Python is the best choice'
print(c[0]+c[1:].lower())
# Out:
# PYTHON IS THE BEST CHOICE
# python is the best choice
# Python is the best choice

# %%
ss = f"{'hi':^12}"
print(ss)
print(ss.lstrip())
print(ss.rstrip())
# Out:
#      hi
# hi
#      hi

# %%
a = "Life is too short"
b = a.replace("too short","웅나")
print(a,b, sep='\n')
# Out:
# Life is too short
# Life is 웅나

# %%
# split - 문자열 나누기 **
a = "Life is too short"
print(a.split())
b = "a:b:c:d:e:f"
print(b.split(':'))

# BaNaNa -> c = b*a*n*a*n*a -> ['b', 'a', 'n', 'a', 'n', 'a']
c = 'BaNaNa'
c = 'BaNaNa'
c2 = '*'.join(c.lower())
print(c2.split('*'))
# Out:
# ['Life', 'is', 'too', 'short']
# ['a', 'b', 'c', 'd', 'e', 'f']
# ['b', 'a', 'n', 'a', 'n', 'a']

# %%
#isalpha - 문자열이 알파벳으로만 구성되어 있는지 확인하기
s = "Life is too short"
ss = s.replace(" ","")
print(ss.isalpha())
# Out:
# True

# %%
#isdigit - 문자열이 숫자로만 구성되어 있는지 확인하기
n ="123456"
print(n.isdigit())
# Out:
# True

# %%
s = "Life is short"
s.startswith("Life")
s.startswith("short")
# Out:
# False

# %%
import requests as req
import json
btc = "https://api4.binance.com/api/v3/ticker/price?symbol=BTCUSDT"
usd = "https://www.koreaexim.go.kr/site/progrzm/financial/exchangeJSON?authkey=5NI1wgZX5OHJXox7MUewT3TwrjmvStFA&data=AP01"
req1 = req.get(btc).json()
req2 = req.get(usd).json()
req3 = float(req1['price']) * float(req2[-1]['deal_bas_r'].replace(',', ''))
print(f"{int(req3):,} 원")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/venv/lib/python3.12/site-packages/urllib3/connection.py:796, in HTTPSConnection.connect(self)
#     794 server_hostname_rm_dot = server_hostname.rstrip(".")
# ...
